# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Homework 1

# %%
df = pd.read_csv('data/data.csv')
intents = df['intent'].value_counts()
print("Suicide rate: " + str(intents['Suicide'] / intents.sum()))

plt.rcParams['figure.figsize'] = (14, 12)
plt.axis('equal')
plt.pie(intents, labels=intents.index, wedgeprops = { 'linewidth' : 1.0, 'edgecolor' : "black" })
# Out:
# Suicide rate: 0.626754764527
# ([<matplotlib.patches.Wedge at 0x2626fe082b0>,
# ...
#   <matplotlib.text.Text at 0x2626f6f2208>])
