# %% [markdown]
# # Table of Contents
#  <p><div class="lev1"><a href="#Task-1.-Compiling-Ebola-Data"><span class="toc-item-num">Task 1.&nbsp;&nbsp;</span>Compiling Ebola Data</a></div>
#  <div class="lev1"><a href="#Task-2.-RNA-Sequences"><span class="toc-item-num">Task 2.&nbsp;&nbsp;</span>RNA Sequences</a></div>
#  <div class="lev1"><a href="#Task-3.-Class-War-in-Titanic"><span class="toc-item-num">Task 3.&nbsp;&nbsp;</span>Class War in Titanic</a></div></p>

# %%
import glob
import os
import re
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from calendar import monthrange
sns.set_context('notebook')
np.set_printoptions(threshold='nan')

# %%
DATA_FOLDER = 'Data' # Use the data folder provided in Tutorial 02 - Intro to Pandas.

# %% [markdown]
# ## Task 1. Compiling Ebola Data
#
# The `DATA_FOLDER/ebola` folder contains summarized reports of Ebola cases from three countries (Guinea, Liberia and Sierra Leone) during the recent outbreak of the disease in West Africa. For each country, there are daily reports that contain various information about the outbreak in several cities in each country.
#
# Use pandas to import these data files into a single `Dataframe`.
# Using this `DataFrame`, calculate for *each country*, the *daily average per month* of *new cases* and *deaths*.
# Make sure you handle all the different expressions for *new cases* and *deaths* that are used in the reports.

# %% [markdown]
# ## Solution
# We first load the csv files for each country

# %%
path_guinea = DATA_FOLDER + '/ebola/guinea_data/' 
path_liberia = DATA_FOLDER + '/ebola/liberia_data/'
path_sierraleone = DATA_FOLDER + '/ebola/sl_data/'

# There should be 22 files for Guinea
all_guinea_files = glob.glob(os.path.join(path_guinea, "*.csv"))    
print('Found '+str(len(all_guinea_files))+' csv files for Guinea')

# There should be 100 files for Liberia
all_liberia_files = glob.glob(os.path.join(path_liberia, "*.csv"))
print('Found '+str(len(all_liberia_files))+' csv files for Liberia')

# There should be 103 files for Sierra Leone
all_sierraleone_files = glob.glob(os.path.join(path_sierraleone, "*.csv"))
print('Found '+str(len(all_sierraleone_files))+' csv files for Sierra Leone')


guinea_df = pd.concat((pd.read_csv(f) for f in all_guinea_files), ignore_index=True)
liberia_df = pd.concat((pd.read_csv(f) for f in all_liberia_files), ignore_index=True)
sierraleone_df = pd.concat((pd.read_csv(f) for f in all_sierraleone_files), ignore_index=True)
# Out:
# Found 22 csv files for Guinea
# Found 100 csv files for Liberia
# Found 103 csv files for Sierra Leone

# %% [markdown]
# We take a look to see how the columns are organized. We see that the event description does not have the same name in the 3 countries. Therefore we rename the corresponding columns so that we can properly concatenate.

# %%
idx = pd.date_range('06-01-2014', '12-30-2014')

# %%
guinea_data = guinea_df.copy()
guinea_data.Date = pd.to_datetime(guinea_data.Date)

with pd.option_context('display.max_rows', None, 'display.max_columns', 100):
    print(guinea_data[['Date', 'Description', 'Totals']].head())

guinea_data = guinea_data[['Date', 'Description', 'Totals']]
guinea_data.Description = guinea_data.Description.str.lower()

death_regexp = re.compile('(?!total)(?!number)(?!cumulative)(?!.*etc).*death.*')
newcase_regexp = re.compile('(?!total)(?!cumulative)(?!.*cum)(?!.*_cum_)' +
               '(?!.*cfr)(?!.*corpse)(?!.*admission)(?!.*sample)(?!pending)(?!percent)'+
               '(?!population)(?!.*noncase)(?!specimen)(?!.*follow-up)(?!.*number)'+
               '(?!.*cte)(?!.*etc)(?!.*rate)(?!.*contact)(?!.*negative)(?!.*death)')

guinea_data_deaths = guinea_data[guinea_data.Description.str.match(death_regexp)][['Date', 'Totals']]
guinea_data_cases = guinea_data[guinea_data.Description.str.match(newcase_regexp)][['Date', 'Totals']]

guinea_data_deaths = guinea_data_deaths.set_index('Date')
guinea_data_cases = guinea_data_cases.set_index('Date')
guinea_data_deaths.columns = ['Registered new deaths']
guinea_data_cases.columns = ['Registered new cases']

guinea_data_cases = guinea_data_cases.astype(float)
guinea_data_deaths = guinea_data_deaths.astype(float)
guinea_data_deaths
# Out:
#         Date                        Description Totals
# 0 2014-08-04              New cases of suspects      5
# 1 2014-08-04             New cases of probables      0
# 2 2014-08-04             New cases of confirmed      4
# 3 2014-08-04  Total new cases registered so far      9
# 4 2014-08-04            Total cases of suspects     11
#             Registered new deaths
# Date
# 2014-08-04                    2.0
# 2014-08-04                    2.0
# 2014-08-04                    0.0
# 2014-08-04                    0.0
# 2014-08-26                    5.0
# 2014-08-26                    0.0
# 2014-08-27                    2.0
# 2014-08-27                    0.0
# 2014-08-30                    5.0
# 2014-08-30                    0.0
# 2014-08-31                    3.0
# 2014-08-31                    0.0
# 2014-09-02                    5.0
# 2014-09-02                    0.0
# 2014-09-04                    5.0
# 2014-09-04                    0.0
# 2014-09-07                    4.0
# 2014-09-07                    0.0
# 2014-09-08                    4.0
# 2014-09-08                    0.0
# 2014-09-09                    7.0
# 2014-09-09                    0.0
# 2014-09-11                    2.0
# 2014-09-11                    0.0
# 2014-09-14                    1.0
# 2014-09-14                    0.0
# 2014-09-16                    3.0
# 2014-09-16                    0.0
# 2014-09-17                    3.0
# 2014-09-17                    0.0
# 2014-09-19                    5.0
# 2014-09-19                    0.0
# 2014-09-21                    0.0
# 2014-09-21                    0.0
# 2014-09-22                    3.0
# 2014-09-22                    0.0
# 2014-09-23                    3.0
# 2014-09-23                    0.0
# 2014-09-24                    3.0
# 2014-09-24                    0.0
# 2014-09-26                    5.0
# 2014-09-26                    0.0
# 2014-09-30                    4.0
# 2014-09-30                    0.0
# 2014-10-01                   15.0
# 2014-10-01                    0.0

# %%
guinea_data_cases = guinea_data_cases.groupby(guinea_data_cases.index).sum()
guinea_data_deaths = guinea_data_deaths.groupby(guinea_data_deaths.index).sum()

guinea_data = guinea_data_cases.merge(guinea_data_deaths, left_index=True, right_index=True, how='outer')

guinea_data = guinea_data.reindex(idx, fill_value=0)
guinea_data.index = guinea_data.index.month

guinea_data=guinea_data.groupby(guinea_data.index).mean()
guinea_data
# Out:
#     Registered new cases  Registered new deaths
# 6                0.00000               0.000000
# 7                0.00000               0.000000
# 8                4.16129               0.612903
# 9               10.70000               1.900000
# 10               1.16129               0.483871
# 11               0.00000               0.000000
# 12               0.00000               0.000000

# %%
guinea_data_deaths = guinea_data_deaths.set_index('Date')
guinea_data_deaths = guinea_data_deaths.astype(float).groupby('Date').sum()

guinea_data_cases = guinea_data_cases.set_index('Date')
guinea_data_cases = guinea_data_cases.astype(float).groupby('Date').sum()


guinea_data_deaths = guinea_data_deaths.reindex(idx, fill_value=0)
guinea_data_cases = guinea_data_cases.reindex(idx, fill_value=0)

guinea_data = guinea_data_cases.join(guinea_data_deaths, how='inner')
guinea_data_deaths.index = guinea_data_deaths.index.month
guinea_data_deaths.index.names = ['Month']
guinea_data_deaths = guinea_data_deaths.groupby('Month').mean()
guinea_data_deaths
guinea_data

# %%
mod_liberia_df = liberia_df.rename(columns = {'Variable' : 'Description'})
mod_liberia_df.Date = pd.to_datetime(mod_liberia_df.Date)
mod_liberia_df['Country'] = 'Liberia'
mod_liberia_df
# Out:
#       Bomi County  Bong County       Date  Gbarpolu County  Grand Bassa  \
# 0             NaN          NaN 2014-06-16              NaN          NaN
# 1             NaN          NaN 2014-06-16              NaN          NaN
# 2             NaN          NaN 2014-06-16              NaN          NaN
# 3             NaN          NaN 2014-06-16              NaN          NaN
# 4             NaN          NaN 2014-06-16              NaN          NaN
# 5             NaN          NaN 2014-06-16              NaN          NaN
# 6             NaN          NaN 2014-06-16              NaN          NaN
# 7             NaN          NaN 2014-06-16              NaN          NaN
# 8             NaN          NaN 2014-06-16              NaN          NaN
# 9             NaN          NaN 2014-06-16              NaN          NaN
# 10            NaN          NaN 2014-06-16              NaN          NaN
# 11            NaN          NaN 2014-06-16              NaN          NaN
# 12            NaN          NaN 2014-06-16              NaN          NaN
# 13            NaN          NaN 2014-06-16              NaN          NaN
# 14            NaN          NaN 2014-06-16              NaN          NaN
# 15            NaN          NaN 2014-06-16              NaN          NaN
# 16            NaN          NaN 2014-06-16              NaN          NaN
# 17            NaN          NaN 2014-06-16              NaN          NaN
# 18            NaN          NaN 2014-06-16              NaN          NaN
# 19            NaN          NaN 2014-06-16              NaN          NaN
# 20            NaN          NaN 2014-06-16              NaN          NaN
# 21            NaN          NaN 2014-06-16              NaN          NaN
# 22            NaN          NaN 2014-06-16              NaN          NaN
# 23            NaN          NaN 2014-06-16              NaN          NaN
# 24            NaN          NaN 2014-06-16              NaN          NaN
# 25            NaN          NaN 2014-06-16              NaN          NaN
# 26            NaN          NaN 2014-06-16              NaN          NaN
# 27            NaN          NaN 2014-06-16              NaN          NaN
# 28            NaN          NaN 2014-06-16              NaN          NaN
# 29            NaN          NaN 2014-06-16              NaN          NaN
# ...           ...          ...        ...              ...          ...
# 3122          NaN          NaN 2014-12-09              NaN          NaN
# 3123          NaN          NaN 2014-12-09              NaN          NaN
# 3124          NaN          NaN 2014-12-09              NaN          NaN
# 3125          NaN          NaN 2014-12-09              NaN          NaN
# 3126          NaN          NaN 2014-12-09              NaN          NaN
# 3127        158.0        125.0 2014-12-09             10.0         70.0
# 3128          NaN          NaN 2014-12-09              NaN          NaN
# 3129          NaN          NaN 2014-12-09              NaN          NaN
# 3130          NaN          NaN 2014-12-09              NaN          NaN
# 3131          NaN          NaN 2014-12-09              NaN          NaN
# 3132          NaN          NaN 2014-12-09              NaN          NaN
# 3133          NaN          NaN 2014-12-09              NaN          NaN
# 3134          NaN          NaN 2014-12-09              NaN          NaN
# 3135          NaN          NaN 2014-12-09              NaN          NaN
# 3136          NaN          NaN 2014-12-09              NaN          NaN
# 3137          NaN          NaN 2014-12-09              NaN          NaN
# 3138          NaN          NaN 2014-12-09              NaN          NaN
# 3139          NaN          NaN 2014-12-09              NaN          NaN
# 3140          NaN          NaN 2014-12-09              NaN          NaN
# 3141          NaN          NaN 2014-12-09              NaN          NaN
# 3142          NaN          NaN 2014-12-09              NaN          NaN
# 3143         82.0        390.0 2014-12-09             26.0         45.0
# 3144         74.0         32.0 2014-12-09              3.0         70.0
# 3145        137.0        135.0 2014-12-09             10.0         43.0
# 3146          NaN          NaN 2014-12-09              NaN          NaN
# 3147          NaN          NaN 2014-12-09              NaN          NaN
# 3148          NaN          NaN 2014-12-09              NaN          NaN
# 3149          NaN          NaN 2014-12-09              NaN          NaN
# 3150          NaN          NaN 2014-12-09              NaN          NaN
# 3151        293.0        557.0 2014-12-09             39.0        158.0
#
#       Grand Cape Mount  Grand Gedeh  Grand Kru  Lofa County  Margibi County  \
# 0                  NaN          NaN        NaN          1.0             NaN
# 1                  NaN          NaN        NaN          0.0             NaN
# 2                  NaN          NaN        NaN         21.0             NaN
# 3                  NaN          NaN        NaN          1.0             NaN
# 4                  NaN          NaN        NaN          4.0             NaN
# 5                  NaN          NaN        NaN          2.0             NaN
# 6                  NaN          NaN        NaN          2.0             NaN
# 7                  NaN          NaN        NaN          8.0             NaN
# 8                  NaN          NaN        NaN          NaN             NaN
# 9                  NaN          NaN        NaN         41.0             NaN
# 10                 NaN          NaN        NaN         95.0             NaN
# 11                 NaN          NaN        NaN         95.0             NaN
# 12                 NaN          NaN        NaN         95.0             NaN
# 13                 NaN          NaN        NaN         11.0             NaN
# 14                 NaN          NaN        NaN          0.0             NaN
# 15                 NaN          NaN        NaN          1.0             NaN
# 16                 NaN          NaN        NaN          5.0             NaN
# 17                 NaN          NaN        NaN          3.0             NaN
# 18                 NaN          NaN        NaN          5.0             NaN
# 19                 NaN          NaN        NaN          NaN             NaN
# 20                 NaN          NaN        NaN          0.0             NaN
# 21                 NaN          NaN        NaN          0.0             NaN
# 22                 NaN          NaN        NaN          0.0             NaN
# 23                 NaN          NaN        NaN          2.0             NaN
# 24                 NaN          NaN        NaN          0.0             NaN
# 25                 NaN          NaN        NaN          1.0             NaN
# 26                 NaN          NaN        NaN          4.0             NaN
# 27                 NaN          NaN        NaN          2.0             NaN
# 28                 NaN          NaN        NaN          8.0             NaN
# 29                 NaN          NaN        NaN          1.0             NaN
# ...                ...          ...        ...          ...             ...
# 3122               NaN          NaN        NaN          NaN             NaN
# 3123               NaN          NaN        NaN          NaN             NaN
# 3124               NaN          NaN        NaN          NaN             NaN
# 3125               NaN          NaN        NaN          NaN             NaN
# 3126               NaN          NaN        NaN          NaN             NaN
# 3127              87.0          5.0       27.0        384.0           557.0
# 3128               NaN          NaN        NaN          NaN             NaN
# 3129               NaN          NaN        NaN          NaN             NaN
# 3130               NaN          NaN        NaN          NaN             NaN
# 3131               NaN          NaN        NaN          NaN             NaN
# 3132               NaN          NaN        NaN          NaN             NaN
# 3133               NaN          NaN        NaN          NaN             NaN
# 3134               NaN          NaN        NaN          NaN             NaN
# 3135               NaN          NaN        NaN          NaN             NaN
# 3136               NaN          NaN        NaN          NaN             NaN
# 3137               NaN          NaN        NaN          NaN             NaN
# 3138               NaN          NaN        NaN          NaN             NaN
# 3139               NaN          NaN        NaN          NaN             NaN
# 3140               NaN          NaN        NaN          NaN             NaN
# 3141               NaN          NaN        NaN          NaN             NaN
# 3142               NaN          NaN        NaN          NaN             NaN
# 3143              47.0          8.0       14.0        171.0           409.0
# 3144              50.0          0.0       18.0        148.0           163.0
# 3145              68.0          2.0        4.0        326.0           383.0
# 3146               NaN          NaN        NaN          NaN             NaN
# 3147               NaN          NaN        NaN          NaN             NaN
# 3148               NaN          NaN        NaN          NaN             NaN
# 3149               NaN          NaN        NaN          NaN             NaN
# 3150               NaN          NaN        NaN          NaN             NaN
# 3151             165.0         10.0       36.0        645.0          1255.0
#
#       Maryland County  Montserrado County  National  Nimba County  \
# 0                 NaN                 0.0       1.0           NaN
# 1                 NaN                 0.0       0.0           NaN
# 2                 NaN                 7.0      28.0           NaN
# 3                 NaN                 0.0       2.0           NaN
# 4                 NaN                 0.0       8.0           NaN
# 5                 NaN                 0.0       6.0           NaN
# 6                 NaN                 0.0       2.0           NaN
# 7                 NaN                 0.0      16.0           NaN
# 8                 NaN                 NaN       NaN           NaN
# 9                 NaN                 0.0      41.0           NaN
# 10                NaN                13.0     108.0           NaN
# 11                NaN                 0.0      95.0           NaN
# 12                NaN                 0.0      95.0           NaN
# 13                NaN                 0.0      11.0           NaN
# 14                NaN                 0.0       NaN           NaN
# 15                NaN                 0.0       1.0           NaN
# 16                NaN                 0.0       5.0           NaN
# 17                NaN                 0.0       3.0           NaN
# 18                NaN                 0.0       5.0           NaN
# 19                NaN                 NaN       0.0           NaN
# 20                NaN                 1.0       1.0           NaN
# 21                NaN                 0.0       0.0           NaN
# 22                NaN                 1.0       1.0           NaN
# 23                NaN                 0.0       2.0           NaN
# 24                NaN                 1.0       1.0           NaN
# 25                NaN                 0.0       1.0           NaN
# 26                NaN                 0.0       4.0           NaN
# 27                NaN                 4.0       6.0           NaN
# 28                NaN                 4.0      12.0           NaN
# 29                NaN                 0.0       1.0           NaN
# ...               ...                 ...       ...           ...
# 3122              NaN                 NaN       NaN           NaN
# 3123              NaN                 NaN       NaN           NaN
# 3124              NaN                 NaN       NaN           NaN
# 3125              NaN                 NaN       NaN           NaN
# 3126              NaN                 NaN       NaN           NaN
# 3127             19.0              1747.0    3290.0          53.0
# 3128              NaN                 NaN       NaN           NaN
# 3129              NaN                 NaN       NaN           NaN
# 3130              NaN                 NaN       NaN           NaN
# 3131              NaN                 NaN       NaN           NaN
# 3132              NaN                 NaN       NaN           NaN
# 3133              NaN                 NaN       NaN           NaN
# 3134              NaN                 NaN       NaN           NaN
# 3135              NaN                 NaN       NaN           NaN
# 3136              NaN                 NaN       NaN           NaN
# 3137              NaN                 NaN       NaN           NaN
# 3138              NaN                 NaN       NaN           NaN
# 3139              NaN                 NaN       NaN           NaN
# 3140              NaN                 NaN       NaN           NaN
# 3141              NaN                 NaN       NaN           NaN
# 3142              NaN                 NaN       NaN           NaN
# 3143             17.0              1726.0    3050.0          78.0
# 3144              2.0               194.0    1801.0         128.0
# 3145              4.0              1676.0    2946.0         114.0
# 3146              NaN                 NaN       NaN           NaN
# 3147              NaN                 NaN       NaN           NaN
# 3148              NaN                 NaN       NaN           NaN
# 3149              NaN                 NaN       NaN           NaN
# 3150              NaN                 NaN       NaN           NaN
# 3151             23.0              4196.0    7797.0         320.0
#
#       River Gee County  RiverCess County  Sinoe County  Unnamed: 18  \
# 0                  NaN               NaN           NaN          NaN
# 1                  NaN               NaN           NaN          NaN
# 2                  NaN               NaN           NaN          NaN
# 3                  NaN               NaN           NaN          NaN
# 4                  NaN               NaN           NaN          NaN
# 5                  NaN               NaN           NaN          NaN
# 6                  NaN               NaN           NaN          NaN
# 7                  NaN               NaN           NaN          NaN
# 8                  NaN               NaN           NaN          NaN
# 9                  NaN               NaN           NaN          NaN
# 10                 NaN               NaN           NaN          NaN
# 11                 NaN               NaN           NaN          NaN
# 12                 NaN               NaN           NaN          NaN
# 13                 NaN               NaN           NaN          NaN
# 14                 NaN               NaN           NaN          NaN
# 15                 NaN               NaN           NaN          NaN
# 16                 NaN               NaN           NaN          NaN
# 17                 NaN               NaN           NaN          NaN
# 18                 NaN               NaN           NaN          NaN
# 19                 NaN               NaN           NaN          NaN
# 20                 NaN               NaN           NaN          NaN
# 21                 NaN               NaN           NaN          NaN
# 22                 NaN               NaN           NaN          NaN
# 23                 NaN               NaN           NaN          NaN
# 24                 NaN               NaN           NaN          NaN
# 25                 NaN               NaN           NaN          NaN
# 26                 NaN               NaN           NaN          NaN
# 27                 NaN               NaN           NaN          NaN
# 28                 NaN               NaN           NaN          NaN
# 29                 NaN               NaN           NaN          NaN
# ...                ...               ...           ...          ...
# 3122               NaN               NaN           NaN          NaN
# 3123               NaN               NaN           NaN          NaN
# 3124               NaN               NaN           NaN          NaN
# 3125               NaN               NaN           NaN          NaN
# 3126               NaN               NaN           NaN          NaN
# 3127               8.0              26.0          14.0          NaN
# 3128               NaN               NaN           NaN          NaN
# 3129               NaN               NaN           NaN          NaN
# 3130               NaN               NaN           NaN          NaN
# 3131               NaN               NaN           NaN          NaN
# 3132               NaN               NaN           NaN          NaN
# 3133               NaN               NaN           NaN          NaN
# 3134               NaN               NaN           NaN          NaN
# 3135               NaN               NaN           NaN          NaN
# 3136               NaN               NaN           NaN          NaN
# 3137               NaN               NaN           NaN          NaN
# 3138               NaN               NaN           NaN          NaN
# 3139               NaN               NaN           NaN          NaN
# 3140               NaN               NaN           NaN          NaN
# 3141               NaN               NaN           NaN          NaN
# 3142               NaN               NaN           NaN          NaN
# 3143               7.0               9.0          21.0          NaN
# 3144               4.0              12.0           3.0          NaN
# 3145               7.0              20.0          16.0          NaN
# 3146               NaN               NaN           NaN          NaN
# 3147               NaN               NaN           NaN          NaN
# 3148               NaN               NaN           NaN          NaN
# 3149               NaN               NaN           NaN          NaN
# 3150               NaN               NaN           NaN          NaN
# 3151              19.0              41.0          40.0          NaN
#
#                                             Description  Country
# 0                                   Specimens collected  Liberia
# 1                         Specimens pending for testing  Liberia
# 2                                Total specimens tested  Liberia
# 3                                 Newly reported deaths  Liberia
# 4                      Total death/s in confirmed cases  Liberia
# 5                       Total death/s in probable cases  Liberia
# 6                      Total death/s in suspected cases  Liberia
# 7     Total death/s in confirmed, probable, suspecte...  Liberia
# 8     Case Fatality Rate (CFR) - Confirmed & Probabl...  Liberia
# 9                               Newly reported contacts  Liberia
# 10                                Total contacts listed  Liberia
# 11                            Currently under follow-up  Liberia
# 12                                        Contacts seen  Liberia
# 13              Contacts who completed 21 day follow-up  Liberia
# 14                           Contacts lost to follow-up  Liberia
# 15                                       New admissions  Liberia
# 16               Total no. currently in Treatment Units  Liberia
# 17                                     Total discharges  Liberia
# 18                       Cumulative admission/isolation  Liberia
# 19                          Newly Reported Cases in HCW  Liberia
# 20                           Cumulative cases among HCW  Liberia
# 21                         Newly Reported deaths in HCW  Liberia
# 22                          Cumulative deaths among HCW  Liberia
# 23                               New Case/s (Suspected)  Liberia
# 24                                New Case/s (Probable)  Liberia
# 25                               New case/s (confirmed)  Liberia
# 26                                Total suspected cases  Liberia
# 27                                 Total probable cases  Liberia
# 28                                Total confirmed cases  Liberia
# 29    Total Number of Confirmed Cases of Sierra Leon...  Liberia
# ...                                                 ...      ...
# 3122                             Total specimens tested  Liberia
# 3123                              Newly reported deaths  Liberia
# 3124                   Total death/s in confirmed cases  Liberia
# 3125                    Total death/s in probable cases  Liberia
# 3126                   Total death/s in suspected cases  Liberia
# 3127  Total death/s in confirmed, \n probable, suspe...  Liberia
# 3128  Case Fatality Rate (CFR) - \n Confirmed & Prob...  Liberia
# 3129                            Newly reported contacts  Liberia
# 3130                              Total contacts listed  Liberia
# 3131                          Currently under follow-up  Liberia
# 3132                                      Contacts seen  Liberia
# 3133         Contacts who completed 21 day \n follow-up  Liberia
# 3134                         Contacts lost to follow-up  Liberia
# 3135                                     New admissions  Liberia
# 3136          Total no. currently in Treatment \n Units  Liberia
# 3137                                   Total discharges  Liberia
# 3138                     Cumulative admission/isolation  Liberia
# 3139                        Newly Reported Cases in HCW  Liberia
# 3140                         Cumulative cases among HCW  Liberia
# 3141                       Newly Reported deaths in HCW  Liberia
# 3142                        Cumulative deaths among HCW  Liberia
# 3143                             New Case/s (Suspected)  Liberia
# 3144                              New Case/s (Probable)  Liberia
# 3145                             New case/s (confirmed)  Liberia
# 3146                              Total suspected cases  Liberia
# 3147                               Total probable cases  Liberia
# 3148                              Total confirmed cases  Liberia
# 3149  Total Number of Confirmed Cases \n of Sierra L...  Liberia
# 3150  Total Number of Confirmed Cases \n of Guinean ...  Liberia
# 3151  Cumulative confirmed, probable and suspected c...  Liberia
#
# [3152 rows x 20 columns]

# %%
mod_sierraleone_df = sierraleone_df.rename(columns={'variable' : 'Description', 'date':'Date'})
mod_sierraleone_df.Date = pd.to_datetime(mod_sierraleone_df.Date)
mod_sierraleone_df['Country'] = 'Sierra Leone'
mod_sierraleone_df = mod_sierraleone_df.drop(['National', 'Western area combined', 'Unnamed: 18'], axis=1)
mod_sierraleone_df.at[3014, 'Port Loko'] = 164 #There was a typo in the data. The sum did not match
mod_sierraleone_df.head()
# Out:
#    34 Military Hospital      Bo  Bo EMC Bombali  Bonthe  Hastings-F/Town  \
# 0                   NaN  654142     NaN  494139  168729              NaN
# 1                   NaN       0     NaN       0       0              NaN
# 2                   NaN       1     NaN       0       0              NaN
# 3                   NaN       1     NaN       0       0              NaN
# 4                   NaN       0     NaN       0       0              NaN
#
#   Kailahun  Kambia  Kenema  Kenema (IFRC)      ...      Police traning School  \
# 0   465048  341690  653013            NaN      ...                        NaN
# 1        0       0       3            NaN      ...                        NaN
# 2        0       0       9            NaN      ...                        NaN
# 3        0       0       0            NaN      ...                        NaN
# 4        0       0       9            NaN      ...                        NaN
#
#   Port Loko Pujehun Tonkolili  Western area  Western area rural  \
# 0    557978  335574    434937           NaN              263619
# 1         1       0         0           NaN                   0
# 2         0       0         0           NaN                   0
# 3         0       0         0           NaN                   0
# 4         2       0         0           NaN                   0
#
#   Western area urban       Date    Description       Country
# 0            1040888 2014-08-12     population  Sierra Leone
# 1                  0 2014-08-12    new_noncase  Sierra Leone
# 2                  0 2014-08-12  new_suspected  Sierra Leone
# 3                  0 2014-08-12   new_probable  Sierra Leone
# 4                  0 2014-08-12  new_confirmed  Sierra Leone
#
# [5 rows x 25 columns]

# %%
data = pd.concat([mod_guinea_df, mod_liberia_df, mod_sierraleone_df])

#Reorganize so we have the description column first
c2 = data[['Description', 'Date', 'Country']]
data.drop(labels=['Description', 'Date', 'Country'], axis=1,inplace = True)
data.insert(0, 'Date', c2['Date'])
data.insert(1, 'Country', c2['Country'])
data.insert(2, 'Description', c2['Description'])
print(data.shape)
data.head()

#data.Description.unique
# Out:
# (7128, 65)
#         Date Country                        Description  34 Military Hospital  \
# 0 2014-08-04  Guinea              New cases of suspects                   NaN
# 1 2014-08-04  Guinea             New cases of probables                   NaN
# 2 2014-08-04  Guinea             New cases of confirmed                   NaN
# 3 2014-08-04  Guinea  Total new cases registered so far                   NaN
# 4 2014-08-04  Guinea            Total cases of suspects                   NaN
#
#   Beyla   Bo  Bo EMC Boffa Bombali  Bomi County  ...    Siguiri Sinoe County  \
# 0   NaN  NaN     NaN     0     NaN          NaN  ...          0          NaN
# 1   NaN  NaN     NaN     0     NaN          NaN  ...          0          NaN
# 2   NaN  NaN     NaN     0     NaN          NaN  ...          0          NaN
# 3   NaN  NaN     NaN     0     NaN          NaN  ...          0          NaN
# 4   NaN  NaN     NaN     0     NaN          NaN  ...          0          NaN
#
#   Telimele Tonkolili Totals Unnamed: 18 Western area Western area rural  \
# 0        0       NaN      5         NaN          NaN                NaN
# 1        0       NaN      0         NaN          NaN                NaN
# 2        0       NaN      4         NaN          NaN                NaN
# 3        0       NaN      9         NaN          NaN                NaN
# 4        0       NaN     11         NaN          NaN                NaN
#
#   Western area urban  Yomou
# 0                NaN    NaN
# 1                NaN    NaN
# 2                NaN    NaN
# 3                NaN    NaN
# 4                NaN    NaN
#
# [5 rows x 65 columns]

# %%
data.Description = data.Description.str.lower()

#Testing the regex for deaths. We don't count admits to Centre Traitement Ebola (CTE-ETC)
print(data['Description'][data.Description.str.match(death_regexp)].unique())

#Testing the regex for new cases. We count suspect cases, don't count admits to Centre Traitement Ebola (CTE-ETC)
data['Description'][data.Description.str.match(newcase_regexp)].unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-697-b4ffe3d02bf6> in <module>()
#       2
#       3 #Testing the regex for deaths. We don't count admits to Centre Traitement Ebola (CTE-ETC)
# ----> 4 print(data['Description'][data.Description.str.match(death_regexp)].unique())
#       5
#       6 #Testing the regex for new cases. We count suspect cases, don't count admits to Centre Traitement Ebola (CTE-ETC)
#
# C:\Users\lkiel\Anaconda3\lib\site-packages\numpy\core\numeric.py in array_str(a, max_line_width, precision, suppress_small)
#    1959
#    1960     """
# -> 1961     return array2string(a, max_line_width, precision, suppress_small, ' ', "", str)
#    1962
#    1963
#
# C:\Users\lkiel\Anaconda3\lib\site-packages\numpy\core\arrayprint.py in array2string(a, max_line_width, precision, suppress_small, separator, prefix, style, formatter)
#     461     else:
#     462         lst = _array2string(a, max_line_width, precision, suppress_small,
# --> 463                             separator, prefix, formatter=formatter)
#     464     return lst
#     465
#
# C:\Users\lkiel\Anaconda3\lib\site-packages\numpy\core\arrayprint.py in _array2string(a, max_line_width, precision, suppress_small, separator, prefix, formatter)
#     316                   prefix="", formatter=None):
#     317
# --> 318     if a.size > _summaryThreshold:
#     319         summary_insert = "..., "
#     320         data = _leading_trailing(a)
#
# TypeError: unorderable types: int() > str()

# %%
newcase_data = data[(data.Description.str.match(newcase_regexp))].copy()
death_data =  data[(data.Description.str.match(death_regexp))].copy()

newcase_data.drop(labels=['Totals', 'Description'], axis=1,inplace = True)
death_data.drop(labels=['Totals', 'Description'], axis=1, inplace = True)

#newcase_data.Date = [datetime.datetime(y , m, 1) for y, m in zip(newcase_data.Date.dt.year, newcase_data.Date.dt.month)]
#death_data.Date = death_data.Date.dt.month

# %%
idx = pd.date_range('06-01-2014', '12-30-2014')

indexed_death_data = death_data.set_index('Date')
indexed_cases_data = newcase_data.set_index('Date')

cases = indexed_cases_data[['Country']].copy()
cases['Total cases'] = indexed_cases_data.iloc[:,1:].astype(float).sum(axis=1)
cases = cases.groupby(['Country', 'Date']).sum()
cases = cases.unstack(level=0)
cases = cases.reindex(idx, fill_value=0)
cases.index = cases.index.month
cases = cases.stack('Country').swaplevel(0,1).sort_index()
cases.index.names = ['Country', 'Date']
cases

deaths = indexed_death_data[['Country']].copy()
deaths['Total deaths'] = indexed_death_data.iloc[:,1:].astype(float).sum(axis=1)
#deaths = deaths.groupby(['Country', 'Date']).sum()
#deaths = deaths.unstack(level=0)
#deaths = deaths.reindex(idx, fill_value=0)
deaths.index = deaths.index.month
#deaths = deaths.stack('Country').swaplevel(0,1).sort_index()
#deaths.index.names = ['Country', 'Date']
deaths
# Out:
#            Country  Total deaths
# Date
# 8           Guinea           2.0
# 8           Guinea           2.0
# 8           Guinea           0.0
# 8           Guinea           0.0
# 8           Guinea          12.0
# 8           Guinea           8.0
# 8           Guinea           0.0
# 8           Guinea           5.0
# 8           Guinea           0.0
# 8           Guinea           2.0
# 8           Guinea           0.0
# 8           Guinea           4.0
# 8           Guinea           0.0
# 8           Guinea           3.0
# 8           Guinea           0.0
# 9           Guinea           5.0
# 9           Guinea           0.0
# 9           Guinea           5.0
# 9           Guinea           0.0
# 9           Guinea           4.0
# 9           Guinea           0.0
# 9           Guinea           4.0
# 9           Guinea           0.0
# 9           Guinea           7.0
# 9           Guinea           0.0
# 9           Guinea           2.0
# 9           Guinea           0.0
# 9           Guinea           1.0
# 9           Guinea           0.0
# 9           Guinea           3.0
# ...            ...           ...
# 11    Sierra Leone         158.0
# 11    Sierra Leone         208.0
# 11    Sierra Leone        1333.0
# 11    Sierra Leone         158.0
# 11    Sierra Leone         208.0
# 11    Sierra Leone        1364.0
# 11    Sierra Leone         158.0
# 11    Sierra Leone         208.0
# 11    Sierra Leone        1397.0
# 11    Sierra Leone         158.0
# 11    Sierra Leone         208.0
# 11    Sierra Leone        1481.0
# 11    Sierra Leone         158.0
# 11    Sierra Leone         208.0
# 11    Sierra Leone        1496.0
# 12    Sierra Leone         158.0
# 12    Sierra Leone         208.0
# 12    Sierra Leone        1549.0
# 12    Sierra Leone         158.0
# 12    Sierra Leone         208.0
# 12    Sierra Leone        1648.0
# 12    Sierra Leone         158.0
# 12    Sierra Leone         208.0
# 12    Sierra Leone        1669.0
# 12    Sierra Leone         158.0
# 12    Sierra Leone         208.0
# 12    Sierra Leone        1708.0
# 12    Sierra Leone           0.0
# 12    Sierra Leone           0.0
# 12    Sierra Leone           0.0
#
# [558 rows x 2 columns]

# %%
cases_grouped = cases.reset_index(level=1)

cases_grouped = cases_grouped.groupby(['Country', 'Date']).mean()
cases_grouped

#deaths_grouped = deaths.reset_index(level=1)

deaths_grouped = deaths.groupby(['Country', 'Date']).mean()
deaths_grouped
# Out:
#                    Total deaths
# Country      Date
# Guinea       8         2.533333
#              9         1.781250
#              10        7.500000
# Liberia      6         2.071429
#              7         4.818182
#              8        24.333333
#              9        36.666667
#              10       28.140000
#              11       13.566667
#              12        0.000000
# Sierra Leone 8       124.683333
#              9       166.919540
#              10      389.380952
#              11      359.777778
#              12      535.866667

# %%
x = np.array(range(8,11))
w = 0.2
plt.bar(x-w, deaths_grouped.loc['Guinea'].values, width=w, align='center')
x = np.array(range(6, 13))
plt.xticks(x, ['Jun.', 'Jul.', 'Aug.', 'Sep.', 'Oct.', 'Nov.', 'Dec.'])
plt.bar(x, deaths_grouped.loc['Liberia'].values, width=w, align='center')
x = np.array(range(8, 13))
plt.bar(x+w, deaths_grouped.loc['Sierra Leone'].values , width=w, align='center')
plt.yscale('log')
plt.show()

# %% [markdown]
# #### Note:
# The columns 'date' in the three dataframes and 'variable' in the dataframes for Liberia and Sierra Leone coalesced.

# %% [markdown]
# ## Task 2. RNA Sequences
#
# In the `DATA_FOLDER/microbiome` subdirectory, there are 9 spreadsheets of microbiome data that was acquired from high-throughput RNA sequencing procedures, along with a 10<sup>th</sup> file that describes the content of each.
#
# Use pandas to import the first 9 spreadsheets into a single `DataFrame`.
# Then, add the metadata information from the 10<sup>th</sup> spreadsheet as columns in the combined `DataFrame`.
# Make sure that the final `DataFrame` has a unique index and all the `NaN` values have been replaced by the tag `unknown`.

# %%
# Write your answer here

# %% [markdown]
# ## Task 3. Class War in Titanic
#
# Use pandas to import the data file `Data/titanic.xls`. It contains data on all the passengers that travelled on the Titanic.

# %%
from IPython.core.display import HTML
HTML(filename=DATA_FOLDER+'/titanic.html')
# Out:
# <hr><h2>Data frame:titanic3</h2>1309 observations and 14 variables, maximum # NAs:1188<hr>
# <TABLE BORDER>
# <tr><td>Name</td><td>Labels</td><td>Units</td><td>Levels</td><td>Storage</td><td>NAs</td></tr>
# <tr><td>pclass</td><td></td><td></td><td><a href="#pclass"><div align=right>  3</div></a></td><td>integer</td><td><div align=right>   0</div></td></tr>
# <tr><td>survived</td><td>Survived</td><td></td><td><div align=right></div></td><td>double</td><td><div align=right>   0</div></td></tr>
# <tr><td>name</td><td>Name</td><td></td><td><div align=right></div></td><td>character</td><td><div align=right>   0</div></td></tr>
# <tr><td>sex</td><td></td><td></td><td><a href="#sex"><div align=right>  2</div></a></td><td>integer</td><td><div align=right>   0</div></td></tr>
# <tr><td>age</td><td>Age</td><td>Year</td><td><div align=right></div></td><td>double</td><td><div align=right> 263</div></td></tr>
# <tr><td>sibsp</td><td>Number of Siblings/Spouses Aboard</td><td></td><td><div align=right></div></td><td>double</td><td><div align=right>   0</div></td></tr>
# <tr><td>parch</td><td>Number of Parents/Children Aboard</td><td></td><td><div align=right></div></td><td>double</td><td><div align=right>   0</div></td></tr>
# <tr><td>ticket</td><td>Ticket Number</td><td></td><td><div align=right></div></td><td>character</td><td><div align=right>   0</div></td></tr>
# <tr><td>fare</td><td>Passenger Fare</td><td>British Pound (\243)</td><td><div align=right></div></td><td>double</td><td><div align=right>   1</div></td></tr>
# <tr><td>cabin</td><td></td><td></td><td><a href="#cabin"><div align=right>187</div></a></td><td>integer</td><td><div align=right>   0</div></td></tr>
# <tr><td>embarked</td><td></td><td></td><td><a href="#embarked"><div align=right>  3</div></a></td><td>integer</td><td><div align=right>   2</div></td></tr>
# <tr><td>boat</td><td></td><td></td><td><a href="#boat"><div align=right> 28</div></a></td><td>integer</td><td><div align=right>   0</div></td></tr>
# <tr><td>body</td><td>Body Identification Number</td><td></td><td><div align=right></div></td><td>double</td><td><div align=right>1188</div></td></tr>
# <tr><td>home.dest</td><td>Home/Destination</td><td></td><td><div align=right></div></td><td>character</td><td><div align=right>   0</div></td></tr>
# </TABLE>
# <hr>
# <TABLE BORDER>
# <tr><td>Variable</td><td>Levels</td></tr>
# <tr><td><a name="pclass">pclass</a></td><td>1st</td></tr>
# <tr><td></td><td>2nd</td></tr>
# <tr><td></td><td>3rd</td></tr>
# <tr><td><a name="sex">sex</a></td><td>female</td></tr>
# <tr><td></td><td>male</td></tr>
# <tr><td><a name="cabin">cabin</a></td><td></td></tr>
# <tr><td></td><td>A10</td></tr>
# <tr><td></td><td>A11</td></tr>
# <tr><td></td><td>A14</td></tr>
# <tr><td></td><td>A16</td></tr>
# <tr><td></td><td>A18</td></tr>
# <tr><td></td><td>A19</td></tr>
# <tr><td></td><td>A20</td></tr>
# <tr><td></td><td>A21</td></tr>
# <tr><td></td><td>A23</td></tr>
# <tr><td></td><td>A24</td></tr>
# <tr><td></td><td>A26</td></tr>
# <tr><td></td><td>A29</td></tr>
# <tr><td></td><td>A31</td></tr>
# <tr><td></td><td>A32</td></tr>
# <tr><td></td><td>A34</td></tr>
# <tr><td></td><td>A36</td></tr>
# <tr><td></td><td>A5</td></tr>
# <tr><td></td><td>A6</td></tr>
# <tr><td></td><td>A7</td></tr>
# <tr><td></td><td>A9</td></tr>
# <tr><td></td><td>B10</td></tr>
# <tr><td></td><td>B101</td></tr>
# <tr><td></td><td>B102</td></tr>
# <tr><td></td><td>B11</td></tr>
# <tr><td></td><td>B18</td></tr>
# <tr><td></td><td>B19</td></tr>
# <tr><td></td><td>B20</td></tr>
# <tr><td></td><td>B22</td></tr>
# <tr><td></td><td>B24</td></tr>
# <tr><td></td><td>B26</td></tr>
# <tr><td></td><td>B28</td></tr>
# <tr><td></td><td>B3</td></tr>
# <tr><td></td><td>B30</td></tr>
# <tr><td></td><td>B35</td></tr>
# <tr><td></td><td>B36</td></tr>
# <tr><td></td><td>B37</td></tr>
# <tr><td></td><td>B38</td></tr>
# <tr><td></td><td>B39</td></tr>
# <tr><td></td><td>B4</td></tr>
# <tr><td></td><td>B41</td></tr>
# <tr><td></td><td>B42</td></tr>
# <tr><td></td><td>B45</td></tr>
# <tr><td></td><td>B49</td></tr>
# <tr><td></td><td>B5</td></tr>
# <tr><td></td><td>B50</td></tr>
# <tr><td></td><td>B51 B53 B55</td></tr>
# <tr><td></td><td>B52 B54 B56</td></tr>
# <tr><td></td><td>B57 B59 B63 B66</td></tr>
# <tr><td></td><td>B58 B60</td></tr>
# <tr><td></td><td>B61</td></tr>
# <tr><td></td><td>B69</td></tr>
# <tr><td></td><td>B71</td></tr>
# <tr><td></td><td>B73</td></tr>
# <tr><td></td><td>B77</td></tr>
# <tr><td></td><td>B78</td></tr>
# <tr><td></td><td>B79</td></tr>
# <tr><td></td><td>B80</td></tr>
# <tr><td></td><td>B82 B84</td></tr>
# <tr><td></td><td>B86</td></tr>
# <tr><td></td><td>B94</td></tr>
# <tr><td></td><td>B96 B98</td></tr>
# <tr><td></td><td>C101</td></tr>
# <tr><td></td><td>C103</td></tr>
# <tr><td></td><td>C104</td></tr>
# <tr><td></td><td>C105</td></tr>
# <tr><td></td><td>C106</td></tr>
# <tr><td></td><td>C110</td></tr>
# <tr><td></td><td>C111</td></tr>
# <tr><td></td><td>C116</td></tr>
# <tr><td></td><td>C118</td></tr>
# <tr><td></td><td>C123</td></tr>
# <tr><td></td><td>C124</td></tr>
# <tr><td></td><td>C125</td></tr>
# <tr><td></td><td>C126</td></tr>
# <tr><td></td><td>C128</td></tr>
# <tr><td></td><td>C130</td></tr>
# <tr><td></td><td>C132</td></tr>
# <tr><td></td><td>C148</td></tr>
# <tr><td></td><td>C2</td></tr>
# <tr><td></td><td>C22 C26</td></tr>
# <tr><td></td><td>C23 C25 C27</td></tr>
# <tr><td></td><td>C28</td></tr>
# <tr><td></td><td>C30</td></tr>
# <tr><td></td><td>C31</td></tr>
# <tr><td></td><td>C32</td></tr>
# <tr><td></td><td>C39</td></tr>
# <tr><td></td><td>C45</td></tr>
# <tr><td></td><td>C46</td></tr>
# <tr><td></td><td>C47</td></tr>
# <tr><td></td><td>C49</td></tr>
# <tr><td></td><td>C50</td></tr>
# <tr><td></td><td>C51</td></tr>
# <tr><td></td><td>C52</td></tr>
# <tr><td></td><td>C53</td></tr>
# <tr><td></td><td>C54</td></tr>
# <tr><td></td><td>C55 C57</td></tr>
# <tr><td></td><td>C6</td></tr>
# <tr><td></td><td>C62 C64</td></tr>
# <tr><td></td><td>C65</td></tr>
# <tr><td></td><td>C68</td></tr>
# <tr><td></td><td>C7</td></tr>
# <tr><td></td><td>C70</td></tr>
# <tr><td></td><td>C78</td></tr>
# <tr><td></td><td>C80</td></tr>
# <tr><td></td><td>C82</td></tr>
# <tr><td></td><td>C83</td></tr>
# <tr><td></td><td>C85</td></tr>
# <tr><td></td><td>C86</td></tr>
# <tr><td></td><td>C87</td></tr>
# <tr><td></td><td>C89</td></tr>
# <tr><td></td><td>C90</td></tr>
# <tr><td></td><td>C91</td></tr>
# <tr><td></td><td>C92</td></tr>
# <tr><td></td><td>C93</td></tr>
# <tr><td></td><td>C95</td></tr>
# <tr><td></td><td>C97</td></tr>
# <tr><td></td><td>C99</td></tr>
# <tr><td></td><td>D</td></tr>
# <tr><td></td><td>D10 D12</td></tr>
# <tr><td></td><td>D11</td></tr>
# <tr><td></td><td>D15</td></tr>
# <tr><td></td><td>D17</td></tr>
# <tr><td></td><td>D19</td></tr>
# <tr><td></td><td>D20</td></tr>
# <tr><td></td><td>D21</td></tr>
# <tr><td></td><td>D22</td></tr>
# <tr><td></td><td>D26</td></tr>
# <tr><td></td><td>D28</td></tr>
# <tr><td></td><td>D30</td></tr>
# <tr><td></td><td>D33</td></tr>
# <tr><td></td><td>D34</td></tr>
# <tr><td></td><td>D35</td></tr>
# <tr><td></td><td>D36</td></tr>
# <tr><td></td><td>D37</td></tr>
# <tr><td></td><td>D38</td></tr>
# <tr><td></td><td>D40</td></tr>
# <tr><td></td><td>D43</td></tr>
# <tr><td></td><td>D45</td></tr>
# <tr><td></td><td>D46</td></tr>
# <tr><td></td><td>D47</td></tr>
# <tr><td></td><td>D48</td></tr>
# <tr><td></td><td>D49</td></tr>
# <tr><td></td><td>D50</td></tr>
# <tr><td></td><td>D56</td></tr>
# <tr><td></td><td>D6</td></tr>
# <tr><td></td><td>D7</td></tr>
# <tr><td></td><td>D9</td></tr>
# <tr><td></td><td>E10</td></tr>
# <tr><td></td><td>E101</td></tr>
# <tr><td></td><td>E12</td></tr>
# <tr><td></td><td>E121</td></tr>
# <tr><td></td><td>E17</td></tr>
# <tr><td></td><td>E24</td></tr>
# <tr><td></td><td>E25</td></tr>
# <tr><td></td><td>E31</td></tr>
# <tr><td></td><td>E33</td></tr>
# <tr><td></td><td>E34</td></tr>
# <tr><td></td><td>E36</td></tr>
# <tr><td></td><td>E38</td></tr>
# <tr><td></td><td>E39 E41</td></tr>
# <tr><td></td><td>E40</td></tr>
# <tr><td></td><td>E44</td></tr>
# <tr><td></td><td>E45</td></tr>
# <tr><td></td><td>E46</td></tr>
# <tr><td></td><td>E49</td></tr>
# <tr><td></td><td>E50</td></tr>
# <tr><td></td><td>E52</td></tr>
# <tr><td></td><td>E58</td></tr>
# <tr><td></td><td>E60</td></tr>
# <tr><td></td><td>E63</td></tr>
# <tr><td></td><td>E67</td></tr>
# <tr><td></td><td>E68</td></tr>

# %% [markdown]
# For each of the following questions state clearly your assumptions and discuss your findings:
# 1. Describe the *type* and the *value range* of each attribute. Indicate and transform the attributes that can be `Categorical`.
# 2. Plot histograms for the *travel class*, *embarkation port*, *sex* and *age* attributes. For the latter one, use *discrete decade intervals*.
# 3. Calculate the proportion of passengers by *cabin floor*. Present your results in a *pie chart*.
# 4. For each *travel class*, calculate the proportion of the passengers that survived. Present your results in *pie charts*.
# 5. Calculate the proportion of the passengers that survived by *travel class* and *sex*. Present your results in *a single histogram*.
# 6. Create 2 equally populated *age categories* and calculate survival proportions by *age category*, *travel class* and *sex*. Present your results in a `DataFrame` with unique index.

# %%
# Write your answer here
